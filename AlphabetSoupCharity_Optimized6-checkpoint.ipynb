# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
#Just want to make sure all the columns are visible
#==================================================
pd.options.display.max_columns=None

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#======================================================
df = application_df.drop(columns=['EIN', 'NAME', ], axis=1)
df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
# Determine the number of unique values in each column.
#======================================================
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#===================================================
app_type_cnt = df['APPLICATION_TYPE'].value_counts()
app_type_cnt
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
#Choose a cutoff value and create a list of application types to be replaced
#use the variable name `application_types_to_replace`
#===================================================================================
application_types_to_replace = list(app_type_cnt[app_type_cnt <500].index)

# %%
#Replace in dataframe
#===============================================================================================
for app in application_types_to_replace:
    df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(app,"Other")

# %%
#Check to make sure binning was successful
#==================================================
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
#Look at CLASSIFICATION value counts for binning
#=================================================
class_val_cnt = df['CLASSIFICATION'].value_counts()
class_val_cnt
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C6100        1
# C1820        1
# C2190        1
# C1570        1
# C8210        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
#You may find it helpful to look at CLASSIFICATION value counts >1
#===================================================================
class_val_cnt.loc[lambda x : x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1600        5
# C1257        5
# C2710        3
# C1260        3
# C0           3
# C3200        2
# C1267        2
# C1246        2
# C1234        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
#Choose a cutoff value and create a list of classifications to be replaced
#use the variable name `classifications_to_replace`
#=========================================================================
classifications_to_replace = list(class_val_cnt[class_val_cnt <500].index)

# %%
#Replace in dataframe
#============================================================================================
for cls in classifications_to_replace:
    df['CLASSIFICATION'] = df['CLASSIFICATION'].replace(cls,"Other")

# %%
#Check to make sure binning was successful
#================================================
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
#Convert categorical data to numeric with `pd.get_dummies`
#============================================================
app_data = pd.get_dummies(df)
app_data
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# ...

# %%
#Split our preprocessed data into our features and target arrays
#=================================================================
X = app_data.drop(['IS_SUCCESSFUL'],1).values
y = app_data['IS_SUCCESSFUL'].values

# %%
#Split the preprocessed data into a training and testing dataset
#=================================================================
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=41)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
#Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#=========================================================================================================
number_of_input_features = len(X_train[0])
hidden_node1 = 100
hidden_node2 = 75
hidden_node3 = 65
hidden_node4 = 50
hidden_node5 = 40

nn = tf.keras.models.Sequential()

# %%
#First hidden layer
#=======================================================================================================
nn.add(tf.keras.layers.Dense(units=hidden_node1, input_dim=number_of_input_features, activation="relu"))

# %%
#Second hidden layer
#=====================================================================
nn.add(tf.keras.layers.Dense(units=hidden_node2, activation="relu"))

# %%
#Third hidden layer
#=====================================================================
nn.add(tf.keras.layers.Dense(units=hidden_node3, activation="relu"))

# %%
#Fourth hidden layer
#=====================================================================
nn.add(tf.keras.layers.Dense(units=hidden_node4, activation="relu"))

# %%
#Fifth hidden layer
#=====================================================================
nn.add(tf.keras.layers.Dense(units=hidden_node5, activation="relu"))

# %%
#Output layer
#============================================================
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
#Check the structure of the model
#================================
nn.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_26 (Dense)            (None, 100)               4500
#
#  dense_27 (Dense)            (None, 75)                7575
#
#  dense_28 (Dense)            (None, 65)                4940
#
#  dense_29 (Dense)            (None, 50)                3300
#
#  dense_30 (Dense)            (None, 40)                2040
#
#  dense_31 (Dense)            (None, 1)                 41
#
# ...
# Total params: 22,396
# Trainable params: 22,396
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile the model
#====================================================================================
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
#Train the model
#=====================================================
fit_model = nn.fit(X_train_scaled, y_train, epochs=250)
# Out:
# Epoch 1/250
# 804/804 [==============================] - 1s 797us/step - loss: 0.5708 - accuracy: 0.7222
# Epoch 2/250
# 804/804 [==============================] - 1s 827us/step - loss: 0.5553 - accuracy: 0.7301
# Epoch 3/250
# 804/804 [==============================] - 1s 964us/step - loss: 0.5504 - accuracy: 0.7325
# Epoch 4/250
# 804/804 [==============================] - 1s 957us/step - loss: 0.5490 - accuracy: 0.7332
# Epoch 5/250
# 804/804 [==============================] - 1s 935us/step - loss: 0.5487 - accuracy: 0.7326
# Epoch 6/250
# 804/804 [==============================] - 1s 873us/step - loss: 0.5468 - accuracy: 0.7352
# Epoch 7/250
# 804/804 [==============================] - 1s 925us/step - loss: 0.5464 - accuracy: 0.73500s - los
# Epoch 8/250
# 804/804 [==============================] - 1s 905us/step - loss: 0.5460 - accuracy: 0.7355
# Epoch 9/250
# 804/804 [==============================] - 1s 795us/step - loss: 0.5442 - accuracy: 0.7364
# Epoch 10/250
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6903 - accuracy: 0.7243 - 170ms/epoch - 633us/step
# Loss: 0.6902815699577332, Accuracy: 0.7243148684501648

# %%
#Export our model to HDF5 file
#===============================
nn.save("AlphaSoupCharity6.h5")

# %% [markdown]
# # Final Observations

# %% [markdown]
# The purpose of this exercise is to use machine learning and neural networks to create a binary classifier that is capable of predicting whether applicants will be successful if funded by Alphabet Soup.

# %% [markdown]
# # Results

# %% [markdown]
# The results of these models can be found in the "AlphabetSoupCharity_Optimization.h5" files

# %% [markdown]
# # Data Preprocessing

# %% [raw]
# The variable that I considered to be the target in my model is the 'IS_SUCCESSFUL' column. 'IS_SUCCESSFUL' was my Y (or my dependent).
#
# The variables that were considered as the features in my model is every other column except for the 'IS_SUCCESSFUL' column and everything else that has been dropped.
#
# Variables that were considered to be neither targets or features are the 'EIN' and 'NAME' columns as they would have no significant value to the analysis.

# %% [markdown]
# # Compiling, Training, and Evaluating the Model

# %% [raw]
# For my first neural network model, it contained two hidden layers where my first layer had 80 neurons and the second layer had 30 neurons. There is also an output layer. Both my first and second hidden layers have the 'relu' activation and the activation of the output layer is 'sigmoid'.

# %% [markdown]
# Unfortunately the neural network model was unable to reach the target model performance of 75%. The accuracy of my model turned out to be around 72.5%.

# %% [raw]
# While trying to optimize my neural network model I tried the following modifications:
#
# 1. Minor mods activation and hidden layer
#
# a) I added a hidden layer
# b) Changed the neurons  hidden_node1 = 100, hidden_node2 = 80, hidden_node3 = 60
# c) Changed the activation to linear.
# d) Epochs set to 43
#
# The change results from the starter code to the first modification were miniscule (72.4) but not in the right direction.

# %% [raw]
# 2. Let's max out those layers
#
# a)I had a total of five hidden layers
# b) Changed the neurons hidden_node1 = 100, hidden_node2 = 75, hidden_node3 = 40, hidden_node4 = 45, hidden_node5 = 30
# c) Added different activations to layer 3 (tanh) and layer 4 (linear)
# d) Epochs set to 73
#
# The results: loss: 0.5679 - accuracy: 0.7240

# %% [raw]
# 3. Output layer and features
#
# a) I removed 'SPECIAL_CONSIDERATIONS' this time as well as ID columns, 'EIN' and 'NAME'.
# b) I only used three hidden layers
# c) Changed the neurons hidden_node1 = 100, hidden_node2 = 80, hidden_node3 = 65
# d) I removed linear from the activation layers and used relu and tanh
# e) I also changed the output activation to relu
# f) Epochs set to 73
#
# The results: loss: 8.1325 - accuracy: 0.4728
#
# By far the worst results so far. I can attribute the large variance to the change in output layer from "sigmoid to "relu"
# Note: Removing 'SPECIAL_CONSIDERATIONS' did not help either

# %% [raw]
# 4. Softmax
#
# a) I added 'SPECIAL_CONSIDERATIONS' back into the ID columns
# b) I used the same amount of layers
# c) I used the same activation in the hidden layers
# d) I changed the output layer to "Softmax"
# e) Epochs set to 43
#
# The results: loss: 0.5566 - accuracy: 0.5272
# Not as bad as the relu output activation but definitely going in the wrong direction.

# %% [markdown]
# 5) Relu
#
# a) I used 5 hidden layers
# b) I used relu for all activation layers except for the output layer which is sigmoid
# c) Epochs set to 250
#
# The results: loss: 0.6903 - accuracy: 0.7243
# Greater loss but the closest to my original results from the starter code (as far as accuracy ).
# I think that you could equate the increase in data loss to to the increase in Epochs

# %% [markdown]
# # Summary

# %% [markdown]
# While I was unable to reach the optimization goal of 75%. I learned that output activation can undoubtly skew you your model result. I found that sigmoid was the best for this exercise. The loss in accuracy from making other attempts such as adding in more hidden layers could be the result of the model being overfit. A different model that could have been used is possibly the Random Forest Classifer which could have avoided the data from bein overfit. The Random Forest Classifier is also well-conditioned and could be deemed to be a more accurate model because of its sufficient number of estimators and tree depth.
